# %%
import re
import string
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

import tensorflow as tf
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPool2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Activation, Dropout
from tensorflow.keras.layers import Conv1D, Embedding, GlobalAveragePooling1D 
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.preprocessing import image

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
# Out:
# 2023-09-09 11:17:12.097568: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df = pd.read_csv('labels.csv')
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
df = df.drop(columns = ['text_ocr', 'overall_sentiment'])
df.head()
# Out:
#      image_name                                     text_corrected  \
# 0   image_1.jpg  LOOK THERE MY FRIEND LIGHTYEAR NOW ALL SOHALIK...
# 1  image_2.jpeg  The best of #10 YearChallenge! Completed in le...
# 2   image_3.JPG  Sam Thorne @Strippin ( Follow Follow Saw every...
# 3   image_4.png              10 Year Challenge - Sweet Dee Edition
# 4   image_5.png  10 YEAR CHALLENGE WITH NO FILTER 47 Hilarious ...
#
#        humour          sarcasm       offensive      motivational
# 0   hilarious          general   not_offensive  not_motivational
# 1   not_funny          general   not_offensive      motivational
# 2  very_funny    not_sarcastic   not_offensive  not_motivational
# 3  very_funny  twisted_meaning  very_offensive      motivational
# 4   hilarious     very_twisted  very_offensive  not_motivational

# %%
df = df.replace({'humour': {'not_funny': 0, 'funny': 1, 'very_funny': 2, 'hilarious':3},
            'sarcasm': {'not_sarcastic': 0, 'general': 1, 'twisted_meaning': 2, 'very_twisted': 3},
            'offensive': {'not_offensive': 0, 'slight': 1, 'very_offensive': 2, 'hateful_offensive': 3},
            'motivational': {'not_motivational': 0, 'motivational': 1}})

# %%
cleaned = df.copy()
cleaned.dropna(inplace=True)
cleaned.isnull().any()
# Out:
# image_name        False
# text_corrected    False
# humour            False
# sarcasm           False
# offensive         False
# motivational      False
# dtype: bool

# %%
width = 100
height = 100
X = []
for i in tqdm(range(cleaned.shape[0])):
    if i in [119, 4799, 6781, 6784, 6786]:
        pass
    else:
        path = 'images/'+cleaned['image_name'][i]
        img = image.load_img(path,target_size=(width,height,3))
        img = image.img_to_array(img)
        img = img/255.0
        X.append(img)
        
X = np.array(X)
# Out:
#  95%|█████████▌| 6663/6987 [01:02<00:02, 109.53it/s]/Users/michal/Desktop/advanced_databases/meme_recommender/env/lib/python3.10/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 100%|██████████| 6987/6987 [01:05<00:00, 106.02it/s]

# %%
X.shape
# Out:
# (6982, 100, 100, 3)

# %%
rows_to_drop = ['image_120.jpg',
              'image_4800.jpg',
              'image_6782.jpg',
              'image_6785.jpg',
              'image_6787.jpg',
              'image_6988.jpg',
              'image_6989.jpg',
              'image_6990.png',
              'image_6991.jpg',
              'image_6992.jpg']

# %%
for images in rows_to_drop:
    cleaned.drop(cleaned[cleaned['image_name'] == images].index, inplace=True)

# %%
target = cleaned.iloc[:,2:]
target.head()
# Out:
#    humour  sarcasm  offensive  motivational
# 0       3        1          0             0
# 1       0        1          0             1
# 2       2        0          0             0
# 3       2        2          2             1
# 4       3        3          2             0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, target, test_size = 0.2)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomContrast([.5,2]),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
  tf.keras.layers.experimental.preprocessing.RandomZoom(0.1)
])

preprocess_input = tf.keras.applications.resnet_v2.preprocess_input

rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)

# %%
plt.figure(figsize=(10, 10))
for i in range(9):
  augmented_image = data_augmentation(X)
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(augmented_image[0])
  plt.axis("off")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
base_model_1 = tf.keras.applications.ResNet50(input_shape=X[0].shape,
                                               include_top=False,
                                               weights='imagenet')
base_model_2 = tf.keras.applications.VGG16(input_shape=X[0].shape,
                                               include_top=False,
                                               weights='imagenet')

# %%
base_model_1.trainable = False
base_model_2.trainable = False

# %%
def image_model():
    image_input = tf.keras.Input(shape=(100, 100, 3), name = 'image_input')
    image_layers = data_augmentation(image_input)
    image_layers = preprocess_input(image_layers)
    layer_bm_1 = base_model_1(image_input, training=False)
    dropout_layer = Dropout(0.2)(layer_bm_1)
    layer_bm_1 = Conv2D(2048, kernel_size=2,padding='valid')(layer_bm_1)
    dropout_layer = Dropout(0.3)(layer_bm_1)
    layer_bm_1 = Dense(512)(dropout_layer)
    dropout_layer = Dropout(0.5)(layer_bm_1)
    layer_bm_2 = base_model_2(image_input, training=False)
    dropout_layer = Dropout(0.4)(layer_bm_2)
    layer_bm_2 = Dense(512)(layer_bm_2)
    dropout_layer = Dropout(0.2)(layer_bm_2)
    layers = tf.keras.layers.concatenate([layer_bm_1, layer_bm_2])
    dropout_layer = Dropout(0.3)(layers)
    image_layers = GlobalAveragePooling2D()(layers)
    image_layers = Dropout(0.5, name = 'dropout_layer')(image_layers)
    return image_input, image_layers

# %%
image_input, image_layers = image_model()

# %%
def model(layer_1, image_input):
    semi_final_layer = tf.keras.layers.Dense(2048, activation='relu')(layer_1)

    prediction_layer_1 = tf.keras.layers.Dense(4, activation='softmax', name = 'humuor')
    prediction_layer_2 = tf.keras.layers.Dense(4, activation='softmax', name = 'sarcasm')
    prediction_layer_3 = tf.keras.layers.Dense(4, activation='softmax', name = 'offensive')
    prediction_layer_4 = tf.keras.layers.Dense(2, activation='softmax', name = 'motivational')

    output_1 = prediction_layer_1(semi_final_layer)
    output_2 = prediction_layer_2(semi_final_layer)
    output_3 = prediction_layer_3(semi_final_layer)
    output_4 = prediction_layer_4(semi_final_layer)

    model = tf.keras.Model(inputs = [image_input] , 
                           outputs = [output_1, output_2, output_3, output_4])
    return model

# %%
model = model(image_layers, image_input)

# %%
import os
# Define the checkpoint directory to store the checkpoints
checkpoint_dir = './training_checkpoints_C'

# Name of the checkpoint files
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

# %%
# You can define any decay function you need.
def decay(epoch):
  if epoch < 5:
    return 1e-3
  elif epoch >= 5 and epoch < 15:
    return 1e-4
  else:
    return 1e-5

# %%
# Callback for printing the LR at the end of each epoch.
class PrintLR(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    print('\nLearning rate for epoch {} is {}'.format(epoch + 1,
                                                      model.optimizer.lr.numpy()))

callbacks = [
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
    tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_prefix,
                                       save_weights_only=True),
    tf.keras.callbacks.LearningRateScheduler(decay),
    PrintLR()
]

# %%
base_learning_rate = 0.0001
losses = {
      "humuor": "sparse_categorical_crossentropy", 
      "sarcasm": "sparse_categorical_crossentropy", 
      "offensive": "sparse_categorical_crossentropy", 
      "motivational": "sparse_categorical_crossentropy"
}
lossWeights = {
      "humuor": 1.0, 
      "sarcasm": 1.0, 
      "offensive": 1.0, 
      "motivational": 1.0
}
metrics = {
      "humuor": "sparse_categorical_accuracy", 
      "sarcasm": "sparse_categorical_accuracy", 
      "offensive": "sparse_categorical_accuracy", 
      "motivational": "sparse_categorical_accuracy"
}
model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
              loss = losses,
              loss_weights= lossWeights,
              metrics=metrics)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
tf.keras.utils.plot_model(model, "multi_input_and_output_model.png", show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history = model.fit(x = {"image_input": X_train},
                    y = {"sarcasm": y_train.sarcasm, 
                         "humuor": y_train.humour, 
                         "offensive": y_train.offensive, 
                         "motivational": y_train.motivational},
                    batch_size=32,
                    epochs=30,
                    validation_data=({"image_input": X_test}, 
                                     {"sarcasm": y_test.sarcasm, 
                                      "humuor": y_test.humour, 
                                      "offensive": y_test.offensive, 
                                      "motivational": y_test.motivational}),
                    callbacks=callbacks
                   )
# Out:
# Epoch 1/30
# 175/175 [==============================] - ETA: 0s - loss: 7.3054 - humuor_loss: 2.2797 - sarcasm_loss: 1.9753 - offensive_loss: 1.7997 - motivational_loss: 1.2506 - humuor_sparse_categorical_accuracy: 0.3112 - sarcasm_sparse_categorical_accuracy: 0.4206 - offensive_sparse_categorical_accuracy: 0.3610 - motivational_sparse_categorical_accuracy: 0.5773
# Learning rate for epoch 1 is 0.0010000000474974513
# 175/175 [==============================] - 943s 5s/step - loss: 7.3054 - humuor_loss: 2.2797 - sarcasm_loss: 1.9753 - offensive_loss: 1.7997 - motivational_loss: 1.2506 - humuor_sparse_categorical_accuracy: 0.3112 - sarcasm_sparse_categorical_accuracy: 0.4206 - offensive_sparse_categorical_accuracy: 0.3610 - motivational_sparse_categorical_accuracy: 0.5773 - val_loss: 4.4203 - val_humuor_loss: 1.3508 - val_sarcasm_loss: 1.2079 - val_offensive_loss: 1.2080 - val_motivational_loss: 0.6537 - val_humuor_sparse_categorical_accuracy: 0.2319 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3994 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 0.0010
# Epoch 2/30
# 175/175 [==============================] - ETA: 0s - loss: 4.4092 - humuor_loss: 1.3228 - sarcasm_loss: 1.2190 - offensive_loss: 1.2024 - motivational_loss: 0.6650 - humuor_sparse_categorical_accuracy: 0.3257 - sarcasm_sparse_categorical_accuracy: 0.4847 - offensive_sparse_categorical_accuracy: 0.3758 - motivational_sparse_categorical_accuracy: 0.6344
# Learning rate for epoch 2 is 0.0010000000474974513
# 175/175 [==============================] - 3292s 19s/step - loss: 4.4092 - humuor_loss: 1.3228 - sarcasm_loss: 1.2190 - offensive_loss: 1.2024 - motivational_loss: 0.6650 - humuor_sparse_categorical_accuracy: 0.3257 - sarcasm_sparse_categorical_accuracy: 0.4847 - offensive_sparse_categorical_accuracy: 0.3758 - motivational_sparse_categorical_accuracy: 0.6344 - val_loss: 4.3211 - val_humuor_loss: 1.3006 - val_sarcasm_loss: 1.1839 - val_offensive_loss: 1.1778 - val_motivational_loss: 0.6589 - val_humuor_sparse_categorical_accuracy: 0.3243 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3465 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 0.0010
# Epoch 3/30
# 175/175 [==============================] - ETA: 0s - loss: 4.3571 - humuor_loss: 1.3114 - sarcasm_loss: 1.1964 - offensive_loss: 1.1919 - motivational_loss: 0.6574 - humuor_sparse_categorical_accuracy: 0.3339 - sarcasm_sparse_categorical_accuracy: 0.4994 - offensive_sparse_categorical_accuracy: 0.3739 - motivational_sparse_categorical_accuracy: 0.6405
# Learning rate for epoch 3 is 0.0010000000474974513
# 175/175 [==============================] - 5334s 31s/step - loss: 4.3571 - humuor_loss: 1.3114 - sarcasm_loss: 1.1964 - offensive_loss: 1.1919 - motivational_loss: 0.6574 - humuor_sparse_categorical_accuracy: 0.3339 - sarcasm_sparse_categorical_accuracy: 0.4994 - offensive_sparse_categorical_accuracy: 0.3739 - motivational_sparse_categorical_accuracy: 0.6405 - val_loss: 4.3323 - val_humuor_loss: 1.2919 - val_sarcasm_loss: 1.2022 - val_offensive_loss: 1.1776 - val_motivational_loss: 0.6606 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3772 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 0.0010
# Epoch 4/30
# 175/175 [==============================] - ETA: 0s - loss: 4.3335 - humuor_loss: 1.3060 - sarcasm_loss: 1.1885 - offensive_loss: 1.1830 - motivational_loss: 0.6561 - humuor_sparse_categorical_accuracy: 0.3441 - sarcasm_sparse_categorical_accuracy: 0.5001 - offensive_sparse_categorical_accuracy: 0.3857 - motivational_sparse_categorical_accuracy: 0.6466
# Learning rate for epoch 4 is 0.0010000000474974513
# 175/175 [==============================] - 7863s 45s/step - loss: 4.3335 - humuor_loss: 1.3060 - sarcasm_loss: 1.1885 - offensive_loss: 1.1830 - motivational_loss: 0.6561 - humuor_sparse_categorical_accuracy: 0.3441 - sarcasm_sparse_categorical_accuracy: 0.5001 - offensive_sparse_categorical_accuracy: 0.3857 - motivational_sparse_categorical_accuracy: 0.6466 - val_loss: 4.3297 - val_humuor_loss: 1.3019 - val_sarcasm_loss: 1.1880 - val_offensive_loss: 1.1798 - val_motivational_loss: 0.6601 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3644 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 0.0010
# Epoch 5/30
# 175/175 [==============================] - ETA: 0s - loss: 4.3216 - humuor_loss: 1.3059 - sarcasm_loss: 1.1834 - offensive_loss: 1.1780 - motivational_loss: 0.6544 - humuor_sparse_categorical_accuracy: 0.3311 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3862 - motivational_sparse_categorical_accuracy: 0.6483
# Learning rate for epoch 5 is 0.0010000000474974513
# 175/175 [==============================] - 5630s 32s/step - loss: 4.3216 - humuor_loss: 1.3059 - sarcasm_loss: 1.1834 - offensive_loss: 1.1780 - motivational_loss: 0.6544 - humuor_sparse_categorical_accuracy: 0.3311 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3862 - motivational_sparse_categorical_accuracy: 0.6483 - val_loss: 4.3164 - val_humuor_loss: 1.3086 - val_sarcasm_loss: 1.1804 - val_offensive_loss: 1.1748 - val_motivational_loss: 0.6526 - val_humuor_sparse_categorical_accuracy: 0.3436 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3966 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 0.0010
# Epoch 6/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2973 - humuor_loss: 1.2980 - sarcasm_loss: 1.1775 - offensive_loss: 1.1730 - motivational_loss: 0.6488 - humuor_sparse_categorical_accuracy: 0.3413 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3819 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 6 is 9.999999747378752e-05
# 175/175 [==============================] - 5508s 31s/step - loss: 4.2973 - humuor_loss: 1.2980 - sarcasm_loss: 1.1775 - offensive_loss: 1.1730 - motivational_loss: 0.6488 - humuor_sparse_categorical_accuracy: 0.3413 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3819 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2948 - val_humuor_loss: 1.2909 - val_sarcasm_loss: 1.1789 - val_offensive_loss: 1.1725 - val_motivational_loss: 0.6526 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3966 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-04
# Epoch 7/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2925 - humuor_loss: 1.2952 - sarcasm_loss: 1.1757 - offensive_loss: 1.1731 - motivational_loss: 0.6485 - humuor_sparse_categorical_accuracy: 0.3488 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3871 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 7 is 9.999999747378752e-05
# 175/175 [==============================] - 5515s 32s/step - loss: 4.2925 - humuor_loss: 1.2952 - sarcasm_loss: 1.1757 - offensive_loss: 1.1731 - motivational_loss: 0.6485 - humuor_sparse_categorical_accuracy: 0.3488 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3871 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2947 - val_humuor_loss: 1.2910 - val_sarcasm_loss: 1.1788 - val_offensive_loss: 1.1722 - val_motivational_loss: 0.6527 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3966 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-04
# Epoch 8/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2915 - humuor_loss: 1.2944 - sarcasm_loss: 1.1756 - offensive_loss: 1.1729 - motivational_loss: 0.6485 - humuor_sparse_categorical_accuracy: 0.3474 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3769 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 8 is 9.999999747378752e-05
# 175/175 [==============================] - 5497s 31s/step - loss: 4.2915 - humuor_loss: 1.2944 - sarcasm_loss: 1.1756 - offensive_loss: 1.1729 - motivational_loss: 0.6485 - humuor_sparse_categorical_accuracy: 0.3474 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3769 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2945 - val_humuor_loss: 1.2906 - val_sarcasm_loss: 1.1789 - val_offensive_loss: 1.1723 - val_motivational_loss: 0.6527 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3966 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-04
# Epoch 9/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2934 - humuor_loss: 1.2957 - sarcasm_loss: 1.1759 - offensive_loss: 1.1726 - motivational_loss: 0.6493 - humuor_sparse_categorical_accuracy: 0.3457 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3857 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 9 is 9.999999747378752e-05
# 175/175 [==============================] - 6406s 37s/step - loss: 4.2934 - humuor_loss: 1.2957 - sarcasm_loss: 1.1759 - offensive_loss: 1.1726 - motivational_loss: 0.6493 - humuor_sparse_categorical_accuracy: 0.3457 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3857 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2966 - val_humuor_loss: 1.2912 - val_sarcasm_loss: 1.1793 - val_offensive_loss: 1.1734 - val_motivational_loss: 0.6526 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3865 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-04
# Epoch 10/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2912 - humuor_loss: 1.2946 - sarcasm_loss: 1.1759 - offensive_loss: 1.1717 - motivational_loss: 0.6490 - humuor_sparse_categorical_accuracy: 0.3452 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3814 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 10 is 9.999999747378752e-05
# 175/175 [==============================] - 4767s 27s/step - loss: 4.2912 - humuor_loss: 1.2946 - sarcasm_loss: 1.1759 - offensive_loss: 1.1717 - motivational_loss: 0.6490 - humuor_sparse_categorical_accuracy: 0.3452 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3814 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2954 - val_humuor_loss: 1.2912 - val_sarcasm_loss: 1.1789 - val_offensive_loss: 1.1729 - val_motivational_loss: 0.6525 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3780 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-04
# Epoch 11/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2898 - humuor_loss: 1.2941 - sarcasm_loss: 1.1749 - offensive_loss: 1.1721 - motivational_loss: 0.6487 - humuor_sparse_categorical_accuracy: 0.3459 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3902 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 11 is 9.999999747378752e-05
# 175/175 [==============================] - 4810s 27s/step - loss: 4.2898 - humuor_loss: 1.2941 - sarcasm_loss: 1.1749 - offensive_loss: 1.1721 - motivational_loss: 0.6487 - humuor_sparse_categorical_accuracy: 0.3459 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3902 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2955 - val_humuor_loss: 1.2911 - val_sarcasm_loss: 1.1792 - val_offensive_loss: 1.1726 - val_motivational_loss: 0.6527 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3951 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-04
# Epoch 12/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2906 - humuor_loss: 1.2945 - sarcasm_loss: 1.1755 - offensive_loss: 1.1719 - motivational_loss: 0.6486 - humuor_sparse_categorical_accuracy: 0.3475 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3801 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 12 is 9.999999747378752e-05
# 175/175 [==============================] - 4845s 28s/step - loss: 4.2906 - humuor_loss: 1.2945 - sarcasm_loss: 1.1755 - offensive_loss: 1.1719 - motivational_loss: 0.6486 - humuor_sparse_categorical_accuracy: 0.3475 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3801 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2996 - val_humuor_loss: 1.2916 - val_sarcasm_loss: 1.1815 - val_offensive_loss: 1.1741 - val_motivational_loss: 0.6525 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3593 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-04
# Epoch 13/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2906 - humuor_loss: 1.2949 - sarcasm_loss: 1.1751 - offensive_loss: 1.1724 - motivational_loss: 0.6482 - humuor_sparse_categorical_accuracy: 0.3484 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3839 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 13 is 9.999999747378752e-05
# 175/175 [==============================] - 4772s 27s/step - loss: 4.2906 - humuor_loss: 1.2949 - sarcasm_loss: 1.1751 - offensive_loss: 1.1724 - motivational_loss: 0.6482 - humuor_sparse_categorical_accuracy: 0.3484 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3839 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2966 - val_humuor_loss: 1.2916 - val_sarcasm_loss: 1.1792 - val_offensive_loss: 1.1734 - val_motivational_loss: 0.6524 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3916 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-04
# Epoch 14/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2878 - humuor_loss: 1.2944 - sarcasm_loss: 1.1734 - offensive_loss: 1.1717 - motivational_loss: 0.6484 - humuor_sparse_categorical_accuracy: 0.3406 - sarcasm_sparse_categorical_accuracy: 0.5015 - offensive_sparse_categorical_accuracy: 0.3764 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 14 is 9.999999747378752e-05
# 175/175 [==============================] - 4751s 27s/step - loss: 4.2878 - humuor_loss: 1.2944 - sarcasm_loss: 1.1734 - offensive_loss: 1.1717 - motivational_loss: 0.6484 - humuor_sparse_categorical_accuracy: 0.3406 - sarcasm_sparse_categorical_accuracy: 0.5015 - offensive_sparse_categorical_accuracy: 0.3764 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2959 - val_humuor_loss: 1.2911 - val_sarcasm_loss: 1.1798 - val_offensive_loss: 1.1724 - val_motivational_loss: 0.6526 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3966 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-04
# Epoch 15/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2898 - humuor_loss: 1.2947 - sarcasm_loss: 1.1752 - offensive_loss: 1.1721 - motivational_loss: 0.6478 - humuor_sparse_categorical_accuracy: 0.3474 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3909 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 15 is 9.999999747378752e-05
# 175/175 [==============================] - 5588s 32s/step - loss: 4.2898 - humuor_loss: 1.2947 - sarcasm_loss: 1.1752 - offensive_loss: 1.1721 - motivational_loss: 0.6478 - humuor_sparse_categorical_accuracy: 0.3474 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3909 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2959 - val_humuor_loss: 1.2914 - val_sarcasm_loss: 1.1793 - val_offensive_loss: 1.1728 - val_motivational_loss: 0.6523 - val_humuor_sparse_categorical_accuracy: 0.3622 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3930 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-04
# Epoch 16/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2850 - humuor_loss: 1.2936 - sarcasm_loss: 1.1731 - offensive_loss: 1.1703 - motivational_loss: 0.6479 - humuor_sparse_categorical_accuracy: 0.3506 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3821 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 16 is 9.999999747378752e-06
# 175/175 [==============================] - 4837s 28s/step - loss: 4.2850 - humuor_loss: 1.2936 - sarcasm_loss: 1.1731 - offensive_loss: 1.1703 - motivational_loss: 0.6479 - humuor_sparse_categorical_accuracy: 0.3506 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3821 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2956 - val_humuor_loss: 1.2911 - val_sarcasm_loss: 1.1794 - val_offensive_loss: 1.1727 - val_motivational_loss: 0.6524 - val_humuor_sparse_categorical_accuracy: 0.3622 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3937 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 17/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2843 - humuor_loss: 1.2941 - sarcasm_loss: 1.1731 - offensive_loss: 1.1698 - motivational_loss: 0.6472 - humuor_sparse_categorical_accuracy: 0.3459 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3864 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 17 is 9.999999747378752e-06
# 175/175 [==============================] - 4939s 28s/step - loss: 4.2843 - humuor_loss: 1.2941 - sarcasm_loss: 1.1731 - offensive_loss: 1.1698 - motivational_loss: 0.6472 - humuor_sparse_categorical_accuracy: 0.3459 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3864 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2957 - val_humuor_loss: 1.2910 - val_sarcasm_loss: 1.1795 - val_offensive_loss: 1.1727 - val_motivational_loss: 0.6525 - val_humuor_sparse_categorical_accuracy: 0.3622 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3908 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 18/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2842 - humuor_loss: 1.2928 - sarcasm_loss: 1.1725 - offensive_loss: 1.1707 - motivational_loss: 0.6481 - humuor_sparse_categorical_accuracy: 0.3470 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3953 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 18 is 9.999999747378752e-06
# 175/175 [==============================] - 3658s 21s/step - loss: 4.2842 - humuor_loss: 1.2928 - sarcasm_loss: 1.1725 - offensive_loss: 1.1707 - motivational_loss: 0.6481 - humuor_sparse_categorical_accuracy: 0.3470 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3953 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2955 - val_humuor_loss: 1.2910 - val_sarcasm_loss: 1.1793 - val_offensive_loss: 1.1727 - val_motivational_loss: 0.6524 - val_humuor_sparse_categorical_accuracy: 0.3622 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3837 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 19/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2849 - humuor_loss: 1.2932 - sarcasm_loss: 1.1735 - offensive_loss: 1.1702 - motivational_loss: 0.6479 - humuor_sparse_categorical_accuracy: 0.3506 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3944 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 19 is 9.999999747378752e-06
# 175/175 [==============================] - 4969s 28s/step - loss: 4.2849 - humuor_loss: 1.2932 - sarcasm_loss: 1.1735 - offensive_loss: 1.1702 - motivational_loss: 0.6479 - humuor_sparse_categorical_accuracy: 0.3506 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3944 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2957 - val_humuor_loss: 1.2911 - val_sarcasm_loss: 1.1794 - val_offensive_loss: 1.1728 - val_motivational_loss: 0.6524 - val_humuor_sparse_categorical_accuracy: 0.3622 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3937 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 20/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2848 - humuor_loss: 1.2930 - sarcasm_loss: 1.1734 - offensive_loss: 1.1707 - motivational_loss: 0.6476 - humuor_sparse_categorical_accuracy: 0.3445 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3851 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 20 is 9.999999747378752e-06
# 175/175 [==============================] - 5430s 31s/step - loss: 4.2848 - humuor_loss: 1.2930 - sarcasm_loss: 1.1734 - offensive_loss: 1.1707 - motivational_loss: 0.6476 - humuor_sparse_categorical_accuracy: 0.3445 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3851 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2958 - val_humuor_loss: 1.2911 - val_sarcasm_loss: 1.1795 - val_offensive_loss: 1.1728 - val_motivational_loss: 0.6524 - val_humuor_sparse_categorical_accuracy: 0.3622 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3937 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 21/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2844 - humuor_loss: 1.2925 - sarcasm_loss: 1.1734 - offensive_loss: 1.1703 - motivational_loss: 0.6481 - humuor_sparse_categorical_accuracy: 0.3488 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3912 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 21 is 9.999999747378752e-06
# 175/175 [==============================] - 5128s 29s/step - loss: 4.2844 - humuor_loss: 1.2925 - sarcasm_loss: 1.1734 - offensive_loss: 1.1703 - motivational_loss: 0.6481 - humuor_sparse_categorical_accuracy: 0.3488 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3912 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2957 - val_humuor_loss: 1.2910 - val_sarcasm_loss: 1.1794 - val_offensive_loss: 1.1728 - val_motivational_loss: 0.6524 - val_humuor_sparse_categorical_accuracy: 0.3622 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3887 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 22/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2842 - humuor_loss: 1.2930 - sarcasm_loss: 1.1736 - offensive_loss: 1.1699 - motivational_loss: 0.6477 - humuor_sparse_categorical_accuracy: 0.3466 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3837 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 22 is 9.999999747378752e-06
# 175/175 [==============================] - 5241s 30s/step - loss: 4.2842 - humuor_loss: 1.2930 - sarcasm_loss: 1.1736 - offensive_loss: 1.1699 - motivational_loss: 0.6477 - humuor_sparse_categorical_accuracy: 0.3466 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3837 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2960 - val_humuor_loss: 1.2912 - val_sarcasm_loss: 1.1794 - val_offensive_loss: 1.1729 - val_motivational_loss: 0.6524 - val_humuor_sparse_categorical_accuracy: 0.3622 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3894 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 23/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2842 - humuor_loss: 1.2936 - sarcasm_loss: 1.1727 - offensive_loss: 1.1700 - motivational_loss: 0.6480 - humuor_sparse_categorical_accuracy: 0.3502 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3905 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 23 is 9.999999747378752e-06
# 175/175 [==============================] - 5222s 30s/step - loss: 4.2842 - humuor_loss: 1.2936 - sarcasm_loss: 1.1727 - offensive_loss: 1.1700 - motivational_loss: 0.6480 - humuor_sparse_categorical_accuracy: 0.3502 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3905 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2958 - val_humuor_loss: 1.2910 - val_sarcasm_loss: 1.1795 - val_offensive_loss: 1.1729 - val_motivational_loss: 0.6524 - val_humuor_sparse_categorical_accuracy: 0.3622 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3837 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 24/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2862 - humuor_loss: 1.2929 - sarcasm_loss: 1.1746 - offensive_loss: 1.1699 - motivational_loss: 0.6488 - humuor_sparse_categorical_accuracy: 0.3495 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3842 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 24 is 9.999999747378752e-06
# 175/175 [==============================] - 5207s 30s/step - loss: 4.2862 - humuor_loss: 1.2929 - sarcasm_loss: 1.1746 - offensive_loss: 1.1699 - motivational_loss: 0.6488 - humuor_sparse_categorical_accuracy: 0.3495 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3842 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2959 - val_humuor_loss: 1.2911 - val_sarcasm_loss: 1.1795 - val_offensive_loss: 1.1729 - val_motivational_loss: 0.6524 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3822 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 25/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2834 - humuor_loss: 1.2920 - sarcasm_loss: 1.1728 - offensive_loss: 1.1709 - motivational_loss: 0.6477 - humuor_sparse_categorical_accuracy: 0.3447 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3903 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 25 is 9.999999747378752e-06
# 175/175 [==============================] - 5205s 30s/step - loss: 4.2834 - humuor_loss: 1.2920 - sarcasm_loss: 1.1728 - offensive_loss: 1.1709 - motivational_loss: 0.6477 - humuor_sparse_categorical_accuracy: 0.3447 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3903 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2960 - val_humuor_loss: 1.2913 - val_sarcasm_loss: 1.1795 - val_offensive_loss: 1.1728 - val_motivational_loss: 0.6524 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3908 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 26/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2813 - humuor_loss: 1.2918 - sarcasm_loss: 1.1716 - offensive_loss: 1.1701 - motivational_loss: 0.6478 - humuor_sparse_categorical_accuracy: 0.3477 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3873 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 26 is 9.999999747378752e-06
# 175/175 [==============================] - 6611s 38s/step - loss: 4.2813 - humuor_loss: 1.2918 - sarcasm_loss: 1.1716 - offensive_loss: 1.1701 - motivational_loss: 0.6478 - humuor_sparse_categorical_accuracy: 0.3477 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3873 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2960 - val_humuor_loss: 1.2913 - val_sarcasm_loss: 1.1795 - val_offensive_loss: 1.1729 - val_motivational_loss: 0.6523 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3772 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 27/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2847 - humuor_loss: 1.2929 - sarcasm_loss: 1.1717 - offensive_loss: 1.1716 - motivational_loss: 0.6485 - humuor_sparse_categorical_accuracy: 0.3477 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3850 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 27 is 9.999999747378752e-06
# 175/175 [==============================] - 5690s 33s/step - loss: 4.2847 - humuor_loss: 1.2929 - sarcasm_loss: 1.1717 - offensive_loss: 1.1716 - motivational_loss: 0.6485 - humuor_sparse_categorical_accuracy: 0.3477 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3850 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2959 - val_humuor_loss: 1.2911 - val_sarcasm_loss: 1.1795 - val_offensive_loss: 1.1730 - val_motivational_loss: 0.6524 - val_humuor_sparse_categorical_accuracy: 0.3622 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3772 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 28/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2845 - humuor_loss: 1.2926 - sarcasm_loss: 1.1737 - offensive_loss: 1.1706 - motivational_loss: 0.6476 - humuor_sparse_categorical_accuracy: 0.3524 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3891 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 28 is 9.999999747378752e-06
# 175/175 [==============================] - 4720s 27s/step - loss: 4.2845 - humuor_loss: 1.2926 - sarcasm_loss: 1.1737 - offensive_loss: 1.1706 - motivational_loss: 0.6476 - humuor_sparse_categorical_accuracy: 0.3524 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3891 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2959 - val_humuor_loss: 1.2912 - val_sarcasm_loss: 1.1795 - val_offensive_loss: 1.1730 - val_motivational_loss: 0.6523 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3744 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 29/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2835 - humuor_loss: 1.2925 - sarcasm_loss: 1.1739 - offensive_loss: 1.1695 - motivational_loss: 0.6477 - humuor_sparse_categorical_accuracy: 0.3486 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3891 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 29 is 9.999999747378752e-06
# 175/175 [==============================] - 4737s 27s/step - loss: 4.2835 - humuor_loss: 1.2925 - sarcasm_loss: 1.1739 - offensive_loss: 1.1695 - motivational_loss: 0.6477 - humuor_sparse_categorical_accuracy: 0.3486 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3891 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2960 - val_humuor_loss: 1.2913 - val_sarcasm_loss: 1.1795 - val_offensive_loss: 1.1729 - val_motivational_loss: 0.6523 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3801 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05
# Epoch 30/30
# 175/175 [==============================] - ETA: 0s - loss: 4.2810 - humuor_loss: 1.2916 - sarcasm_loss: 1.1725 - offensive_loss: 1.1693 - motivational_loss: 0.6476 - humuor_sparse_categorical_accuracy: 0.3463 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3823 - motivational_sparse_categorical_accuracy: 0.6487
# Learning rate for epoch 30 is 9.999999747378752e-06
# 175/175 [==============================] - 4758s 27s/step - loss: 4.2810 - humuor_loss: 1.2916 - sarcasm_loss: 1.1725 - offensive_loss: 1.1693 - motivational_loss: 0.6476 - humuor_sparse_categorical_accuracy: 0.3463 - sarcasm_sparse_categorical_accuracy: 0.5017 - offensive_sparse_categorical_accuracy: 0.3823 - motivational_sparse_categorical_accuracy: 0.6487 - val_loss: 4.2964 - val_humuor_loss: 1.2912 - val_sarcasm_loss: 1.1798 - val_offensive_loss: 1.1730 - val_motivational_loss: 0.6524 - val_humuor_sparse_categorical_accuracy: 0.3629 - val_sarcasm_sparse_categorical_accuracy: 0.5018 - val_offensive_sparse_categorical_accuracy: 0.3830 - val_motivational_sparse_categorical_accuracy: 0.6421 - lr: 1.0000e-05

# %%
model.save("model_C.keras")
